# %% [markdown]
# ## Ejercicios de la semana 2

# %%
edad = 16
if edad >= 18:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")
# Out:
# Eres menor de edad

# %%
calificacion = 667
if calificacion >= 90:
    print ("A")
elif calificacion >= 80:
    print ("B")
elif calificacion >= 70:
    print ("C")
elif calificacion >= 60:
    print ("D")
else:
    print ("E")
# Out:
# A

# %% [markdown]
# ## Operdores lógicos

# %%
PL1 = True
PL2 = False
print(PL1 or PL2)
# Out:
# True

# %%
edad = 65
tipo = "adulto_mayor"
es_mayor = edad >= 18
print (es_mayor)
aplica_descuento = (edad >= 18) and (tipo == "adulto mayor")
print (aplica_descuento)
# Out:
# True
# False

# %%
edad = int(input("Ingresa tu edad"))
if (edad < 0):
    print("Aguanta, no hay edades menores a cero")
else:
    print("Ahora si vamos a trabajar con edades reales")
# Out:
# Ahora si vamos a trabajar con edades reales

# %%
precio = int(input("Ingresa el costo"))
if tipo == "adulto_mayor":
    descuento = precio * 0.12          # 5.40
elif tipo == "profesor" or tipo == "estudiante":
    descuento = precio * 0.10          # 4.50
else:
    descuento = 0
total = precio - descuento
print(f"Total a pagar: ${total:.2f}")  # Ej. adulto mayor: $39.60
# Out:
# Total a pagar: $29.92

# %% [markdown]
# #### Ejercicio 1: Mayor de edad

# %%
edad = int(input("Ingresa tu edad"))
if edad >= 18:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")
# Out:
# Eres menor de edad

# %% [markdown]
# #### Ejercicio 2: Número par o impar

# %%
numero = int(input("Ingrese un número entero"))
if (numero % 2 == 0):
    print("Es un número par")
else:
    print("Es un número impar")
# Out:
# Es un número par

# %% [markdown]
# #### Ejercicio 3:Calificación aprobatoria

# %%
calificacion = int(input("Ingresa tu calificacion"))
if calificacion >= 6:
    print("Aprobado")
else:
    print("Reprobado")
# Out:
# Aprobado

# %% [markdown]
# #### Ejercicio 4: Clasificacion por rango de edad con elif

# %%
edad = int(input("ingresa tu edad:"))
if edad >= 18:
    print("Eres un adulto")
elif edad >= 13:
    print("Eres un adolescente")
elif edad >= 3:
    print("Eres un niño")
else:
    print("Eres un bebé")
# Out:
# Eres un adulto

# %% [markdown]
# #### Ejercicio 5: Descuento por tipo de visitante

# %%
precio = 45
tipo = input("Ingresa el tipo de visitante (adulto mayor, profesor, estudiante, otro):")
if tipo == "adulto mayor":
    print(f"total a pagar: ${precio * 0.88:.2f}")
elif tipo == "profesor" or tipo == "estudiante":
    print(f"Total a pagar: ${precio * 0.90:.2f}")
else:
    print(f"Total a pagar: ${precio:.2f}")
# Out:
# Total a pagar: $40.50

# %% [markdown]
# #### Ejercicio 6: Acceso con operador and

# %%
edad = int(input("Ingresa tu edad: "))
credencial = input("Tienes credencial vigente? (si/no):")
if edad >= 18 and credencial == "si":
    print("Acceso permitido")
else:
    print("Acceso denegado")
# Out:
# Acceso denegado

# %% [markdown]
# #### Ejercicio 7: Detección de número negativo con or

# %%
numero1 = int(input("Ingresa el primer número:"))
numero2 = int(input("Ingresa el segundo número:"))
if numero1 or numero2 < 0:
    print("Hay un numero negativo")
else:
    print("No hay numeros negativos")
# Out:
# Hay un numero negativo

# %% [markdown]
# #### Ejercicio 8: Positivo y par con anidamiento

# %% [markdown]
# ## Bloque 2

# %% [markdown]
# #### Ejercicio 10: Contador del 1 al 5

# %%
contador = 1
while contador <= 5:
    print(contador)
    contador += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### Prototipo actividad evaluable
# Desarrollar un programa en **Python** para cobrar las entradas de los visitantes que desean recorrer el **Museo de Antropología e Historia**, calculando el precio adecuado para cada visitante y aplicando descuentos por tipo de visitante bajo estrictas condiciones lógicas. El programa debe procesar a los visitantes mediante un **ciclo controlado**, aplicar los descuentos con una **tabla de verdad** que garantice un único descuento por boleto y desplegar el **total detallado** de todas las personas ingresadas.
#
# **Precios base de entrada:**
# | Tipo de visitante | Precio |
# | :--- | :---: |
# | Niños menores de 3 años | Gratis ($0) |
# | Menores de edad (de 3 a 17 años) | $30 |
# | Mayores de 18 años | $45 |
#
# **Tabla de descuentos oficial:**
# | Tipo de visitante | Descuento |
# | :--- | :---: |
# | Adulto mayor | 12% |
# | Profesor | 10% |
# | Estudiante | 10% |
#
# Este reto integra las **estructuras de decisión** `if/elif/else` y los operadores lógicos (Tema 5), el **ciclo `while`** con `break` y `continue` (Tema 6), la **depuración con PDB** para garantizar un código libre de errores (Tema 7) y el **ciclo `for`** con acumuladores y procesamiento repetitivo (Tema 8).

# %%
personas = int(input("Bienvenido al museo de A.H. ¿Cuántas personas son?:"))
for i in range(personas):
    edad = int(input("Ingresa edad de la persona"))
if edad >= 18:
    costo = 45
elif edad >= 3:
    costo = 30
else:
    costo = 0
print(f"El costo de la entrada es: ${costo:.2f}")
