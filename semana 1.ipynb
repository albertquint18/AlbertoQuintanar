# %% [markdown]
# # sesion 1

# %% [markdown]
# ## variables
#
# Las variables de python son tipos de datos que tienen diferentes formas
# - numericas
#     Enteros
#     Flotante
# - cadenas de caracteres
# - Booleanos
# - Compuestos

# %%
nombre = "Alberto"
edad = "18"
es_estudiante = True
está_activo = None

print(type (nombre))
print(type (edad))
print(type (es_estudiante))
print(type (está_activo))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>

# %%
nombre = "Alberto"
edad = "18"

print("Hola", nombre, "ya vi que tienes", edad, "años de vida")
# Out:
# Hola Alberto ya vi que tienes 18 años de vida

# %% [markdown]
# ## Algoritmo para calcular velocidad

# %%
distancia = input("ingrese la distancia en kilómetros:")
tiempo = input("ingrese el tiempo en horas:")

print("El dato distancia es de tipo: ", type(distancia))
print("El dato tiempo es de tipo: ", type(tiempo))

velocidad = distancia / tiempo
print("la velocidad promedio es:" , velocidad)

# %%
a = 4
b = 6

print(a + b)
print(a == b)
# Out:
# 10
# False

# %%
name = input("Alberto:")
age = input("18:")

print("Hi", name, "i know you're", age, "years old")
# Out:
# Running cells with '.venv (3.14.7.final.0) (Python 3.14.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/QUINTANAR/Fundamentos de programación/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
name = input("Ingrese su nombre: ")
age = input("Ingrese su edad: ")
print("Hi", name, "i know you're ", age, "years old")

# %%
name = input("Ingrese su nombre: ")
age = input("Ingrese su edad: ")
print("Hi", name, "i know you're ", age, "years old")
# Out:
# Hi el niño del oxxo i know you're  69 years old
